# %% [markdown]
# # LGMVIP April-22

# %% [markdown]
# ## AUTHOR - PRABIN KUMAR MOHANTA

# %% [markdown]
# ## BEGINNER LEVEL TASK

# %% [markdown]
# ### Task1-Iris Flowers Classification ML Project :

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",header=None)

# %%
data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
data.rename(columns={0:'s_length',1:'s_width',2:'p_length',3:'p_width',4:'class'},inplace=True)

# %%
data.head()
# Out:
#    s_length  s_width  p_length  p_width        class
# 0       5.1      3.5       1.4      0.2  Iris-setosa
# 1       4.9      3.0       1.4      0.2  Iris-setosa
# 2       4.7      3.2       1.3      0.2  Iris-setosa
# 3       4.6      3.1       1.5      0.2  Iris-setosa
# 4       5.0      3.6       1.4      0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   s_length  150 non-null    float64
#  1   s_width   150 non-null    float64
#  2   p_length  150 non-null    float64
#  3   p_width   150 non-null    float64
#  4   class     150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe(include='all')
# Out:
#           s_length     s_width    p_length     p_width        class
# count   150.000000  150.000000  150.000000  150.000000          150
# unique         NaN         NaN         NaN         NaN            3
# top            NaN         NaN         NaN         NaN  Iris-setosa
# freq           NaN         NaN         NaN         NaN           50
# mean      5.843333    3.054000    3.758667    1.198667          NaN
# std       0.828066    0.433594    1.764420    0.763161          NaN
# min       4.300000    2.000000    1.000000    0.100000          NaN
# 25%       5.100000    2.800000    1.600000    0.300000          NaN
# 50%       5.800000    3.000000    4.350000    1.300000          NaN
# 75%       6.400000    3.300000    5.100000    1.800000          NaN
# max       7.900000    4.400000    6.900000    2.500000          NaN

# %%
data.isnull()
# Out:
#      s_length  s_width  p_length  p_width  class
# 0       False    False     False    False  False
# 1       False    False     False    False  False
# 2       False    False     False    False  False
# 3       False    False     False    False  False
# 4       False    False     False    False  False
# ..        ...      ...       ...      ...    ...
# 145     False    False     False    False  False
# 146     False    False     False    False  False
# 147     False    False     False    False  False
# 148     False    False     False    False  False
# 149     False    False     False    False  False
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# s_length    0
# s_width     0
# p_length    0
# p_width     0
# class       0
# dtype: int64

# %%
data.nunique(axis=0)
# Out:
# s_length    35
# s_width     23
# p_length    43
# p_width     22
# class        3
# dtype: int64

# %%
data['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 3

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (147, 5)

# %%
data.tail()
# Out:
#      s_length  s_width  p_length  p_width           class
# 145       6.7      3.0       5.2      2.3  Iris-virginica
# 146       6.3      2.5       5.0      1.9  Iris-virginica
# 147       6.5      3.0       5.2      2.0  Iris-virginica
# 148       6.2      3.4       5.4      2.3  Iris-virginica
# 149       5.9      3.0       5.1      1.8  Iris-virginica

# %%
data.reset_index(drop=True,inplace=True)
data.tail()
# Out:
#      s_length  s_width  p_length  p_width           class
# 142       6.7      3.0       5.2      2.3  Iris-virginica
# 143       6.3      2.5       5.0      1.9  Iris-virginica
# 144       6.5      3.0       5.2      2.0  Iris-virginica
# 145       6.2      3.4       5.4      2.3  Iris-virginica
# 146       5.9      3.0       5.1      1.8  Iris-virginica

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,15))
a=1
for i, column in enumerate(data.columns):
    if data[column].dtype != 'object':
        plt.subplot(2,2,a)
        sns.distplot(data[column],kde=True,color='b',bins=10,hist_kws={'color':'r'})
        plt.xlabel(column)
        a+=1

plt.show()

# %%
plt.figure(figsize=(20,20))
a=1
for i, column in enumerate(data.columns):
    if data[column].dtype != 'object':
        plt.subplot(2,2,a)
        sns.violinplot(y=data[column],orient='h')
        plt.xlabel(column)
        a+=1

plt.show()

# %%
sns.countplot(data['class'],palette="mako")
plt.xlabel(column)
plt.show()

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data['s_length'],data['p_length'],hue=data['class'])
# Out:
# <AxesSubplot:xlabel='s_length', ylabel='p_length'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data['s_width'],data['p_width'],hue=data['class'])
# Out:
# <AxesSubplot:xlabel='s_width', ylabel='p_width'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data['s_length'],data['s_width'],hue=data['class'])
# Out:
# <AxesSubplot:xlabel='s_length', ylabel='s_width'>

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data['p_length'],data['p_width'],hue=data['class'])
# Out:
# <AxesSubplot:xlabel='p_length', ylabel='p_width'>

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(), annot = True, cmap='mako')
plt.title("Correlation Between Features")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
data['class']=LabelEncoder().fit_transform(data['class'])
data.head()
# Out:
#    s_length  s_width  p_length  p_width  class
# 0       5.1      3.5       1.4      0.2      0
# 1       4.9      3.0       1.4      0.2      0
# 2       4.7      3.2       1.3      0.2      0
# 3       4.6      3.1       1.5      0.2      0
# 4       5.0      3.6       1.4      0.2      0

# %%
from sklearn.model_selection import train_test_split

# Segregate features and labels into separate variables
x,y = data.to_numpy()[:,0:4] , data.to_numpy()[:,4]

# Split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
models =[LogisticRegression(),KNeighborsClassifier(),GaussianNB(),RandomForestClassifier(),SVC()]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
for modl in models:
    model=modl.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    score=accuracy_score(y_test,y_pred)
    cm=confusion_matrix(y_test,y_pred)
    cr=classification_report(y_test,y_pred)
    print("For "+type(model).__name__+" is------\n")
    print("Accuracy is",score)
    print("\nConfusion matrix is-")
    print(cm)
    print("\nClassification report is-")
    print(cr)
    print('\n\n--------------------------------------------------------------------------------------------\n\n')
# Out:
# For LogisticRegression is------
#
# Accuracy is 0.9387755102040817
#
# Confusion matrix is-
# [[18  0  0]
#  [ 0 12  1]
#  [ 0  2 16]]
#
# Classification report is-
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        18
#          1.0       0.86      0.92      0.89        13
#          2.0       0.94      0.89      0.91        18
#
#     accuracy                           0.94        49
#    macro avg       0.93      0.94      0.93        49
# weighted avg       0.94      0.94      0.94        49
#
#
#
# --------------------------------------------------------------------------------------------
#
#
# For KNeighborsClassifier is------
#
# Accuracy is 0.9591836734693877
#
# Confusion matrix is-
# [[18  0  0]
#  [ 0 12  1]
#  [ 0  1 17]]
#
# Classification report is-
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        18
# ...
